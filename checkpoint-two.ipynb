# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My Business issue: To increase knowledge of stock market. S&P 500 is a stock market index tracking the stock performance of 500 largest companies listed on stock exchanges in the United States. It is one of the most commonly followed equity indices. In most caes stock follow the trend of S&P 500, My goal is to see how much my 6 selected stocks follow the S&P trend, can I predict the trend of common stock based on S&P 500.
#
# My dataset:I will be using different 7 datasets to figure out correlation of 6 popular companies compared to S&P 500 and future trend prediction: All 7 has Public Domain license and above 9 usability
#
# https://www.kaggle.com/datasets/andrewmvd/sp-500-stocks?select=sp500_index.csv
# https://www.kaggle.com/datasets/rajkumarpandey02/tesla-inc-tsla-stock-price
# https://www.kaggle.com/datasets/jainilcoder/netflix-stock-price-prediction
# https://www.kaggle.com/datasets/tarunpaparaju/apple-aapl-historical-stock-data
# https://www.kaggle.com/datasets/kannan1314/amazon-stock-price-all-time
# https://www.kaggle.com/datasets/kalilurrahman/facebook-stock-data-live-and-latest
# https://www.kaggle.com/datasets/vijayvvenkitesh/microsoft-stock-time-series-analysis
#
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
#import needed libraires with aliases
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

#read in dataset giving aliases same as their respective NASDAQ ticker symbol for stocks to compare it with S&P index.
spy = pd.read_csv("sp500_index.csv")
amzn = pd.read_csv("Amazon.csv")
aapl = pd.read_csv("Apple.csv")
nflx = pd.read_csv("Netflix.csv")
tsla = pd.read_csv("Tesla.csv")
meta = pd.read_csv("Facebook.csv")
msft = pd.read_csv("Microsoft.csv")

# Want to see if the dataframe was properly imported and kind of data is stored in each column
spy.info()
amzn.info()
aapl.info()
nflx.info()
tsla.info()
meta.info()
msft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    2520 non-null   object
#  1   S&P500  2520 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 39.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6155 entries, 0 to 6154
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       6155 non-null   object
#  1   Open       6155 non-null   float64
#  2   High       6155 non-null   float64
#  3   Low        6155 non-null   float64
#  4   Close      6155 non-null   float64
#  5   Adj Close  6155 non-null   float64
#  6   Volume     6155 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 336.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2518 entries, 0 to 2517
# Data columns (total 6 columns):
# ...

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
#see how many rows of data is stored in dataset
spy.shape
# Out:
# (2520, 2)

# %%
#see how many rows of data is stored in dataset
amzn.shape
# Out:
# (6155, 7)

# %%
#see how many rows of data is stored in dataset
aapl.shape
# Out:
# (2518, 6)

# %%
#see how many rows of data is stored in dataset
nflx.shape
# Out:
# (1009, 7)

# %%
#see how many rows of data is stored in dataset
tsla.shape
# Out:
# (3024, 7)

# %%
#see how many rows of data is stored in dataset
meta.shape
# Out:
# (2359, 8)

# %%
#see how many rows of data is stored in dataset
msft.shape
# Out:
# (1511, 6)

# %%
#see what kind of data is stored in each column of each dataset
spy.head(3)
# Out:
#          Date   S&P500
# 0  2013-04-01  1562.17
# 1  2013-04-02  1570.25
# 2  2013-04-03  1553.69

# %%
#see what kind of data is stored in each column of each dataset
amzn.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800

# %%
#see what kind of data is stored in each column of each dataset
aapl.head(3)
# Out:
#        Date  Close            Volume   Open   High    Low
# 0  3/1/2010  29.86   137,312,041.00   29.39  29.93  29.35
# 1  3/2/2010  29.84   141,486,282.00   29.99  30.12  29.68
# 2  3/3/2010  29.90    92,846,488.00   29.85  29.98  29.71

# %%
#see what kind of data is stored in each column of each dataset
nflx.head(3)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500

# %%
#see what kind of data is stored in each column of each dataset
tsla.head(3)
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  2011-01-03  1.789333  1.800000  1.726667  1.774667   1.774667  19245000
# 1  2011-01-04  1.777333  1.796667  1.734667  1.778000   1.778000  17811000
# 2  2011-01-05  1.765333  1.793333  1.746000  1.788667   1.788667  21700500

# %%
#see what kind of data is stored in each column of each dataset
meta.head(3)
# Out:
#          Date       Open   High        Low      Close     Volume  Dividends  \
# 0  2012-05-18  42.049999  45.00  38.000000  38.230000  573576400          0
# 1  2012-05-21  36.529999  36.66  33.000000  34.029999  168192700          0
# 2  2012-05-22  32.610001  33.59  30.940001  31.000000  101786600          0
#
#    Stock Splits
# 0             0
# 1             0
# 2             0

# %%
#see what kind of data is stored in each column of each dataset
msft.head(3)
# Out:
#                 Date   Open   High    Low  Close    Volume
# 0  4/1/2015 16:00:00  40.60  40.76  40.31  40.72  36865322
# 1  4/2/2015 16:00:00  40.66  40.74  40.12  40.29  37487476
# 2  4/6/2015 16:00:00  40.34  41.78  40.18  41.55  39223692

# %%
# Making sure data do not have duplicates
spy.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
spy.isnull().sum()
# Out:
# Date      0
# S&P500    0
# dtype: int64

# %%
# Making sure data do not have duplicates
amzn.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
amzn.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Making sure data do not have duplicates
aapl.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
aapl.isnull().sum()
# Out:
# Date       0
# Close      0
#  Volume    0
#  Open      0
#  High      0
#  Low       0
# dtype: int64

# %%
# Making sure data do not have duplicates
nflx.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
nflx.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Making sure data do not have duplicates
tsla.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
tsla.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# Making sure data do not have duplicates
meta.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
meta.isnull().sum()
# Out:
# Date            0
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
# Making sure data do not have duplicates
msft.duplicated().sum()
# Out:
# 0

# %%
# Making sure data do not null values
msft.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
# comparing individual stock againt S&P500
# gr = spy.plot(kind='line',x="Date", y="S&P500", color="Red", title = 'S&P 500 Vs Amazon stock Price');
# amzn.plot(ax = gr, kind='line',x="Date", y="Close", label = 'Amazon', color="green");
# plt.xticks(rotation = 45)

# gr2 = spy.plot(kind='line',x="Date", y="S&P500", color="Red",title = 'S&P 500 Vs Apple stock Price');
# aapl.plot(ax = gr2, kind='line',x="Date", y="Close", label = 'Apple', color="black");
# plt.xticks(rotation = 45)

# gr3 = spy.plot(kind='line',x="Date", y="S&P500", color="Red",title = 'S&P 500 Vs Netflix stock Price');
# nflx.plot(ax = gr3, kind='line',x="Date", y="Close",label = 'Netflix', color="brown");
# plt.xticks(rotation = 45)

# gr4 = spy.plot(kind='line',x="Date", y="S&P500", color="Red",title = 'S&P 500 Vs Tesla stock Price');
# tsla.plot(ax = gr4, kind='line',x="Date", y="Close",label = 'Tesla', color="purple");
# plt.xticks(rotation = 45)

# gr5 = spy.plot(kind='line',x="Date", y="S&P500", color="Red",title = 'S&P 500 Vs Facebook stock Price');
# meta.plot(ax = gr5, kind='line',x="Date", y="Close",label = 'Facebook', color="orange");
# plt.xticks(rotation = 45)

# gr6 = spy.plot(kind='line',x="Date", y="S&P500", color="Red",title = 'S&P 500 Vs Microsoft stock Price');
# msft.plot(ax = gr6, kind='line',x="Date", y="Close", label = 'Microsoft', color="blue");
# plt.xticks(rotation = 45)

# ploting Line graphs for all 7 stock prices to see trend repetition
spy.plot(kind='line',x="Date", y="S&P500", color="Red");
plt.xticks(rotation = 45)
amzn.plot(kind='line',x="Date", y="Close",label = 'Amazon', color="green");
plt.xticks(rotation = 45)
aapl.plot(kind='line',x="Date", y="Close",label = 'Apple',  color="black");
plt.xticks(rotation = 45)
nflx.plot(kind='line',x="Date", y="Close",label = 'Netflix', color="brown");
plt.xticks(rotation = 45)
tsla.plot(kind='line',x="Date", y="Close", label = 'Tesla',color="purple");
plt.xticks(rotation = 45)
meta.plot(kind='line',x="Date", y="Close", label = 'Facebook',color="orange");
plt.xticks(rotation = 45)
msft.plot(kind='line',x="Date", y="Close", label = 'Microsoft', color="blue");
plt.xticks(rotation = 45)
# Out:
# (array([-200.,    0.,  200.,  400.,  600.,  800., 1000., 1200., 1400.,
#         1600.]),
#  [Text(-200.0, 0, '6/16/2020 16:00:00'),
#   Text(0.0, 0, '4/1/2015 16:00:00'),
#   Text(200.0, 0, '1/15/2016 16:00:00'),
#   Text(400.0, 0, '10/31/2016 16:00:00'),
#   Text(600.0, 0, '8/17/2017 16:00:00'),
#   Text(800.0, 0, '6/5/2018 16:00:00'),
#   Text(1000.0, 0, '3/22/2019 16:00:00'),
#   Text(1200.0, 0, '1/7/2020 16:00:00'),
#   Text(1400.0, 0, '10/21/2020 16:00:00'),
#   Text(1600.0, 0, '')])

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# --- Price of S&P 500 is much higher that individual stock price, its difficult to plot in one graph
#
#
# 2. Do you have any concerns about your dataset?
# --- All the dataset are not from same date range
#
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# --- All data should be from same date range,
# --- all in cronological order.
# --- Prefer to use For loop to make plots.
# --- Data should be grouped in date (monthly or 6monthly to see actual corelation)
# --- Date column should be cleaned up.
